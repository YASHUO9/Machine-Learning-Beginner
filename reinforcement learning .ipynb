# %%
import sys
print(sys.version)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]

# %%
import gym
import keras
import random 
import math
import numpy as np
from collections import deque

# %%
#Setup the Open ai gym environment

env = gym.make('CartPole-v0')

for i in range(20):
    observation = env.reset()
    for t in range(10000):
        env.render()
#         print(observation)
        action = env.action_space.sample()
        print(list(env.step((action))))
        observation,reward,done,info,ok = list(env.step(action))
        
        
                   
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
# Out:
# [array([ 0.04369908, -0.20327838, -0.03618175,  0.2473548 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.0316762 , -0.5925343 , -0.02066647,  0.8110886 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00407817, -0.5921869 ,  0.0174993 ,  0.8031258 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01571175, -0.2026756 ,  0.04388179,  0.23407783], dtype=float32), 1.0, False, False, {}]
# [array([-0.01992941, -0.20399068,  0.04767441,  0.26315415], dtype=float32), 1.0, False, False, {}]
# [array([-0.03200441, -0.20541841,  0.06434719,  0.29493776], dtype=float32), 1.0, False, False, {}]
# [array([-0.03633818, -0.20732538,  0.0707104 ,  0.33721602], dtype=float32), 1.0, False, False, {}]
# [array([-0.04855226, -0.599489  ,  0.09048137,  0.9673651 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.07645608, -0.60213536,  0.13556959,  1.03067   ], dtype=float32), 1.0, False, False, {}]
# [array([-0.09667982, -0.21638158,  0.17185174,  0.5436813 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.10148822,  0.16807395,  0.18891922,  0.07974421], dtype=float32), 1.0, False, False, {}]
# [array([-0.09092561,  0.552012  ,  0.18755624, -0.3749442 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.0650045 ,  0.93625146,  0.16799492, -0.8341207 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.02370489,  0.9319653 ,  0.12992023, -0.7335244 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00964062,  0.5387587 ,  0.10719096, -0.07625877], dtype=float32), 1.0, False, False, {}]
# [array([0.02726133, 0.14581652, 0.11063032, 0.5722811 ], dtype=float32), 1.0, False, False, {}]
# [array([0.02916428, 0.14260598, 0.14002927, 0.645713  ], dtype=float32), 1.0, False, False, {}]
# [array([0.03872696, 0.13860454, 0.16094747, 0.73692405], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04033243, -0.2552835 ,  0.19719844,  1.4178916 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 19 timesteps
# [array([-0.01286004, -0.21009439, -0.04834461,  0.25028828], dtype=float32), 1.0, False, False, {}]
# [array([-0.0251518 , -0.59898007, -0.03279207,  0.80605674], dtype=float32), 1.0, False, False, {}]
# [array([-0.05300415, -0.98853576,  0.005094  ,  1.3756526 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.09644929, -0.98899275,  0.06600554,  1.3875719 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.1321242 , -0.9909717 ,  0.11608173,  1.4367977 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.17568998, -0.99410015,  0.1800854 ,  1.5190214 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 6 timesteps
# [array([-0.04407538, -0.19380477, -0.00823571,  0.32165414], dtype=float32), 1.0, False, False, {}]
# [array([-0.05572765, -0.19366138,  0.01043195,  0.31847838], dtype=float32), 1.0, False, False, {}]
# [array([-0.05957466,  0.19618748,  0.01738358, -0.2582314 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.04782977,  0.58600515,  0.00131133, -0.8341891 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.02048749,  0.58619195, -0.03790164, -0.8386374 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.0009315 ,  0.19729397, -0.0658366 , -0.28314224], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00307778, -0.19085777, -0.07173802,  0.257366  ], dtype=float32), 1.0, False, False, {}]
# [array([-0.0084371 , -0.57901096, -0.05605896,  0.79756576], dtype=float32), 1.0, False, False, {}]
# [array([-0.03548374, -0.96789026, -0.01866565,  1.3519309 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.078097 , -1.3579919,  0.0411473,  1.9339966], dtype=float32), 1.0, False, False, {}]
# [array([-0.13632742, -1.3592474 ,  0.12461019,  1.9720976 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.18682519, -0.972735  ,  0.19846176,  1.4830219 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 12 timesteps
# [array([ 0.03108965,  0.19063608, -0.04712804, -0.27995127], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04263032,  0.58221674, -0.06446943, -0.8959331 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.06983767,  0.9742346 , -0.10655138, -1.5254872 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.11273175,  1.3668082 , -0.17404985, -2.181353  ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 4 timesteps
# [array([-0.0454806 , -0.17132333, -0.00653697,  0.25679556], dtype=float32), 1.0, False, False, {}]
# [array([-0.0562341 , -0.17120974,  0.00954713,  0.25428542], dtype=float32), 1.0, False, False, {}]
# [array([-0.0591828 , -0.1715541 ,  0.01392542,  0.26189265], dtype=float32), 1.0, False, False, {}]
# [array([-0.06995132, -0.17202424,  0.03034197,  0.2723507 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.07293877,  0.2172428 ,  0.03557679, -0.29178968], dtype=float32), 1.0, False, False, {}]
# [array([-0.06035711,  0.6065325 ,  0.01828013, -0.8562104 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.03219845,  0.60626364, -0.02170588, -0.85004455], dtype=float32), 1.0, False, False, {}]
# [array([-0.01184429,  0.2168862 , -0.04999207, -0.28402382], dtype=float32), 1.0, False, False, {}]
# [array([-0.00705633,  0.21838593, -0.05582291, -0.31723332], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00559652,  0.22005507, -0.07470728, -0.354511  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01051903,  0.22226386, -0.08352328, -0.403617  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02333361,  0.61472654, -0.10602402, -1.0414698 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05184983,  1.0075463 , -0.15416273, -1.6949853 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.09608226,  1.4005755 , -0.22869097, -2.3759456 ], dtype=float32), 1.0, True, False, {}]
# Episode finished after 14 timesteps
# [array([ 0.00267215,  0.1895962 , -0.03382356, -0.32825217], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01416773,  0.58084446, -0.05301674, -0.93653065], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04131741,  0.5825077 , -0.09665516, -0.97601736], dtype=float32), 1.0, False, False, {}]
# [array([ 0.06074369,  0.19546713, -0.13047937, -0.46121866], dtype=float32), 1.0, False, False, {}]
# [array([ 0.06470118, -0.19046943, -0.1439506 ,  0.03321424], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05322648, -0.5760832 , -0.13774148,  0.52152216], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02632432, -0.96218586, -0.11195453,  1.0178937 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01603243, -0.9594884 , -0.06612805,  0.9535265 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.05049304, -0.95797753, -0.03424109,  0.9183224 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.092705  , -1.3475333 ,  0.00812637,  1.4877162 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.15051073, -1.73828   ,  0.07353921,  2.0871396 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.2239576 , -2.129987  ,  0.16331443,  2.7273746 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 12 timesteps
# [array([ 0.02879299, -0.21320441, -0.03766607,  0.23720616], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01637353, -0.60241187, -0.02256647,  0.79990363], dtype=float32), 1.0, False, False, {}]
# [array([-0.01161905, -0.9922518 ,  0.01513967,  1.3760178 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.05521528, -0.9929581 ,  0.07612796,  1.3942984 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.09105168, -0.9951812 ,  0.12654106,  1.4497697 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.13478753, -1.3881043 ,  0.1911197 ,  2.1158879 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 6 timesteps
# [array([-0.04659535, -0.19753292,  0.01119323,  0.30239013], dtype=float32), 1.0, False, False, {}]
# [array([-0.05840226, -0.19793606,  0.02921268,  0.31137928], dtype=float32), 1.0, False, False, {}]
# [array([-0.06242582,  0.19135404,  0.03600127, -0.25324342], dtype=float32), 1.0, False, False, {}]
# [array([-0.05087986,  0.5806175 ,  0.02024926, -0.8171338 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.02375838,  0.58028334, -0.018161  , -0.80947345], dtype=float32), 1.0, False, False, {}]
# [array([-0.00444442,  0.19079283, -0.04480163, -0.24089421], dtype=float32), 1.0, False, False, {}]
# [array([-0.00070179,  0.19213563, -0.04887297, -0.27058902], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01089931,  0.1935989 , -0.0658503 , -0.30317745], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01476078,  0.19554982, -0.0725532 , -0.3464452 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02650427,  0.58775747, -0.09270402, -0.97770923], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05393926,  0.59046006, -0.13821846, -1.042477  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.0736968 ,  0.20479394, -0.17499162, -0.55746305], dtype=float32), 1.0, False, False, {}]
# [array([ 0.07804277, -0.179547  , -0.19263327, -0.09592827], dtype=float32), 1.0, False, False, {}]
# [array([ 0.06702261, -0.17416173, -0.19194517, -0.21687019], dtype=float32), 1.0, False, False, {}]
# [array([ 0.0640016 , -0.16879323, -0.20755121, -0.33843914], dtype=float32), 1.0, False, False, {}]
# Episode finished after 15 timesteps
# [array([-0.0074391 ,  0.21734847, -0.01845445, -0.33235526], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00516243,  0.21796529, -0.03771756, -0.34612703], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00998973,  0.21913218, -0.04595155, -0.3719986 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02266989,  0.6106972 , -0.0669677 , -0.9878123 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05101681,  0.6127278 , -0.11273903, -1.0364313 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.07165677,  0.6159497 , -0.14909092, -1.1126807 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.10022939,  1.0094453 , -0.20030802, -1.7891281 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 7 timesteps
# [array([ 0.04501539,  0.24424425, -0.01985093, -0.27466506], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05869315,  0.2448861 , -0.03681507, -0.2889501 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.06459703, -0.14417808, -0.04275611,  0.27084374], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05494018, -0.14303866, -0.02634443,  0.24553089], dtype=float32), 1.0, False, False, {}]
# [array([ 0.0531284 , -0.1423587 , -0.02254069,  0.23050018], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04353819, -0.14178164, -0.00761091,  0.2177097 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04177152, -0.14162683, -0.004804  ,  0.21428937], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03220539, -0.5317944 ,  0.00959084,  0.7979726 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00702857, -0.53227043,  0.04742344,  0.80909914], dtype=float32), 1.0, False, False, {}]
# [array([-0.01037342, -0.14365694,  0.07423948,  0.25972044], dtype=float32), 1.0, False, False, {}]
# [array([-0.01223994,  0.24422921,  0.07926081, -0.27525482], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00140736,  0.24205925,  0.06291724, -0.22694351], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00717049, -0.14981088,  0.06007644,  0.39541844], dtype=float32), 1.0, False, False, {}]
# [array([-0.00274035, -0.15161403,  0.08211323,  0.4358896 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.00492753,  0.23596776,  0.09423462, -0.09252363], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00838426,  0.62331676,  0.08530311, -0.61623305], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03719359,  0.62111646,  0.05536091, -0.5661728 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05812119,  0.6197298 ,  0.03890595, -0.5350495 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.08680146,  0.6187871 ,  0.01190048, -0.5138046 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.1076472 ,  0.22835448, -0.00272352,  0.07579949], dtype=float32), 1.0, False, False, {}]
# [array([0.11287972, 0.22841077, 0.00614491, 0.07455846], dtype=float32), 1.0, False, False, {}]
# [array([ 0.12591681,  0.61845607,  0.00331249, -0.50644386], dtype=float32), 1.0, False, False, {}]
# [array([ 0.15455656,  0.6185034 , -0.02277801, -0.5075502 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.17540082,  0.22907348, -0.03737164,  0.05998509], dtype=float32), 1.0, False, False, {}]
# [array([ 0.18067242, -0.16008237, -0.02935901,  0.62170726], dtype=float32), 1.0, False, False, {}]
# [array([ 1.7037514e-01, -5.4967099e-01,  1.1751567e-03,  1.1923165e+00],
#       dtype=float32), 1.0, False, False, {}]
# [array([ 0.14448555, -0.940226  ,  0.05472884,  1.785758  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.10296267, -1.3318266 ,  0.13234279,  2.4141548 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04576964, -1.3343737 ,  0.2355134 ,  2.5117364 ], dtype=float32), 1.0, True, False, {}]
# Episode finished after 29 timesteps
# [array([ 0.04598568, -0.17246802,  0.00631956,  0.3339796 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03518273, -0.17274119,  0.02557212,  0.3400878 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03216806,  0.2166509 ,  0.03348543, -0.2267182 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04472665,  0.60598105,  0.01877799, -0.7920741 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.07286308,  0.9959233 , -0.01863931, -1.3705509 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.11660701,  1.3868994 , -0.07943042, -1.9756666 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.17600027,  1.778765  , -0.16478103, -2.6186767 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 7 timesteps
# [array([-0.03417113,  0.22337414, -0.03906177, -0.2698562 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.02132302,  0.22455972, -0.05595088, -0.2962468 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01622626, -0.16390434, -0.06231024,  0.250815  ], dtype=float32), 1.0, False, False, {}]
# [array([-0.02666602, -0.16220418, -0.04682971,  0.21303903], dtype=float32), 1.0, False, False, {}]
# [array([-0.02923901,  0.22926036, -0.04444974, -0.3998443 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01615413,  0.23062614, -0.0665707 , -0.43048   ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01081147, -0.15746269, -0.07837037,  0.10854688], dtype=float32), 1.0, False, False, {}]
# [array([-0.0209883 , -0.15526232, -0.0686892 ,  0.05980888], dtype=float32), 1.0, False, False, {}]
# [array([-0.02327807,  0.23679133, -0.07256763, -0.56691533], dtype=float32), 1.0, False, False, {}]
# [array([-0.0098852 ,  0.23896405, -0.10153691, -0.61637914], dtype=float32), 1.0, False, False, {}]
# [array([-0.004198  , -0.14793834, -0.12101097, -0.10260341], dtype=float32), 1.0, False, False, {}]
# [array([-0.0139795 , -0.14448735, -0.12007134, -0.1792481 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01582665,  0.24875742, -0.13380164, -0.8362183 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.00194294,  0.25255054, -0.17388217, -0.9258508 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.00431106,  0.25734568, -0.20624848, -1.0390188 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 15 timesteps
# [array([ 0.04575428,  0.14894186,  0.024871  , -0.3121305 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05560714,  0.14832321,  0.00669104, -0.29837528], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05763573,  0.1482181 ,  0.00065174, -0.29604423], dtype=float32), 1.0, False, False, {}]
# [array([ 0.06746671,  0.53852606, -0.01703957, -0.8828596 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.09291474,  0.53922045, -0.05831377, -0.8992425 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.11059785,  0.5410347 , -0.08880751, -0.94114804], dtype=float32), 1.0, False, False, {}]
# [array([ 0.13616322,  0.54364073, -0.13283771, -1.0032351 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.15404643,  0.5473813 , -0.16800332, -1.0916708 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.17987946,  0.9411594 , -0.21847688, -1.7775126 ], dtype=float32), 1.0, True, False, {}]
# Episode finished after 9 timesteps
# [array([-0.02992686,  0.2250802 ,  0.00867643, -0.31869173], dtype=float32), 1.0, False, False, {}]
# [array([-0.0170237 ,  0.6151672 , -0.00986992, -0.9005827 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01148807,  0.61567134, -0.0518086 , -0.91253597], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03222724,  0.22720857, -0.08279084, -0.3667527 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03743851, -0.16036779, -0.0921515 ,  0.16166262], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02714999, -0.15779631, -0.08044003,  0.10457397], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02476168, -0.15553866, -0.08259583,  0.05461191], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01466321, -0.5432575 , -0.0751009 ,  0.58604246], dtype=float32), 1.0, False, False, {}]
# [array([-0.01094698, -0.5413258 , -0.04629696,  0.54223454], dtype=float32), 1.0, False, False, {}]
# [array([-0.02868519, -0.5401827 , -0.03074565,  0.5166239 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.05418601, -0.92969465, -0.00442393,  1.085654  ], dtype=float32), 1.0, False, False, {}]
# [array([-0.09527507, -0.9298562 ,  0.04482806,  1.0897193 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.12857924, -0.5412038 ,  0.0828511 ,  0.54042745], dtype=float32), 1.0, False, False, {}]
# [array([-0.14635009, -0.543663  ,  0.09915879,  0.5956491 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.1720238 , -0.93645674,  0.1294287 ,  1.2432702 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.21341254, -1.3295689 ,  0.18576482,  1.9100982 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 16 timesteps
# [array([ 0.02321894, -0.22256154,  0.04980717,  0.34999925], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01040061, -0.61421984,  0.06996641,  0.9679782 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.01808795, -0.6163302 ,  0.11496186,  1.0183642 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.0388728 , -0.619613  ,  0.15060669,  1.0958956 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.06759232, -1.0131422 ,  0.20116042,  1.7730489 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 5 timesteps
# [array([ 0.02954565,  0.1823289 , -0.00318444, -0.32382706], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04074215,  0.18251038, -0.02201124, -0.32788795], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04414653,  0.18322831, -0.02941353, -0.3437849 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05538622,  0.5743644 , -0.04920115, -0.9494821 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.08227576,  0.57592684, -0.09333497, -0.98663914], dtype=float32), 1.0, False, False, {}]
# [array([ 0.1014377 ,  0.57865924, -0.12756115, -1.0506926 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.1285153 ,  0.58223283, -0.17618582, -1.1377685 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.14795591,  0.19784398, -0.21704347, -0.6809675 ], dtype=float32), 1.0, True, False, {}]
# Episode finished after 8 timesteps
# [array([ 0.04638395, -0.2097406 ,  0.0351793 ,  0.32885882], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03408223, -0.21082994,  0.05440497,  0.35317907], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02953519, -0.21246894,  0.06303127,  0.38956127], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01711728, -0.21435374,  0.08485115,  0.43185785], dtype=float32), 1.0, False, False, {}]
# [array([ 0.01241962,  0.17313875,  0.09682997, -0.09470446], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02321738,  0.5604021 ,  0.08782916, -0.6166382 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.04950931,  0.94821393,  0.05788805, -1.1484431 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.09132428,  0.9469984 ,  0.00647066, -1.1190367 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.1253001 ,  0.5568914 , -0.03239669, -0.5366943 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.1436827 ,  0.55794996, -0.04821843, -0.56036174], dtype=float32), 1.0, False, False, {}]
# [array([ 0.16991599,  0.55944914, -0.07678242, -0.5944151 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.1884146 ,  0.56174624, -0.09520816, -0.6461483 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.21481065,  0.9544516 , -0.12747572, -1.2918298 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.25691855,  1.3475019 , -0.18574335, -1.9578294 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 14 timesteps
# [array([ 0.04639037, -0.18392205, -0.05027282,  0.25806072], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03514609, -0.18256524, -0.03442215,  0.22792354], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03175542, -0.18165009, -0.03137199,  0.20769769], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02059622, -0.57103735, -0.01741161,  0.77430373], dtype=float32), 1.0, False, False, {}]
# [array([-0.00614284, -0.5707681 ,  0.01930363,  0.76817125], dtype=float32), 1.0, False, False, {}]
# [array([-0.02507654, -0.57151085,  0.04429954,  0.78502846], dtype=float32), 1.0, False, False, {}]
# [array([-0.05185101, -0.57293046,  0.08182636,  0.81804365], dtype=float32), 1.0, False, False, {}]
# [array([-0.07088998, -0.18540238,  0.10923081,  0.2919743 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.0744379 , -0.18856159,  0.1157831 ,  0.36229828], dtype=float32), 1.0, False, False, {}]
# [array([-0.08591159, -0.19190326,  0.13681166,  0.43757102], dtype=float32), 1.0, False, False, {}]
# [array([-0.08972877,  0.19381599,  0.14938211, -0.05250362], dtype=float32), 1.0, False, False, {}]
# [array([-0.07812215,  0.5792456 ,  0.14244048, -0.53704935], dtype=float32), 1.0, False, False, {}]
# [array([-0.05109508,  0.96519744,  0.11606595, -1.0301952 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.00861913,  0.962401  ,  0.06977604, -0.9633186 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.02595718,  0.9607977 ,  0.03751854, -0.92591614], dtype=float32), 1.0, False, False, {}]
# [array([ 0.068281  ,  1.3502648 , -0.00513131, -1.493245  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.12619527,  1.7409457 , -0.07074673, -2.0908782 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.19974831,  1.74273   , -0.16065562, -2.148468  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.26559317,  1.7461685 , -0.2418131 , -2.2577462 ], dtype=float32), 1.0, True, False, {}]
# Episode finished after 19 timesteps
# [array([-0.02490837, -0.23124361,  0.00587075,  0.27318454], dtype=float32), 1.0, False, False, {}]
# [array([-0.03806221, -0.62172794,  0.02268871,  0.86394536], dtype=float32), 1.0, False, False, {}]
# [array([-0.0668398 , -1.0127702 ,  0.06324111,  1.4686162 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.11126733, -1.0146406 ,  0.1282207 ,  1.5178514 ], dtype=float32), 1.0, False, False, {}]
# [array([-0.14798577, -1.0180329 ,  0.18393348,  1.6056383 ], dtype=float32), 1.0, False, False, {}]
# Episode finished after 5 timesteps
# [array([-0.04873269,  0.22527985,  0.03359306, -0.24943341], dtype=float32), 1.0, False, False, {}]
# [array([-0.03582897,  0.224394  ,  0.01797771, -0.22977683], dtype=float32), 1.0, False, False, {}]
# [array([-0.03076069,  0.22394738,  0.01475262, -0.21990867], dtype=float32), 1.0, False, False, {}]
# [array([-1.7904637e-02,  6.1382991e-01,  1.9641357e-04, -7.9730374e-01],
#       dtype=float32), 1.0, False, False, {}]
# [array([ 0.01055094,  0.61403835, -0.03754816, -0.80222505], dtype=float32), 1.0, False, False, {}]
# [array([ 0.03122073,  0.6152846 , -0.06402438, -0.83066374], dtype=float32), 1.0, False, False, {}]
# [array([ 0.05975083,  1.0072982 , -0.10349317, -1.4596183 ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.10396731,  1.0101221 , -0.16834068, -1.534097  ], dtype=float32), 1.0, False, False, {}]
# [array([ 0.14051735,  1.014393  , -0.22498922, -1.6461427 ], dtype=float32), 1.0, True, False, {}]
# Episode finished after 9 timesteps
